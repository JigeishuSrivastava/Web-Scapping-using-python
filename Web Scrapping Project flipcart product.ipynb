# %%
pip install flask
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/101.7 kB ? eta -:--:--
#    ---------------------------------------- 101.7/101.7 kB 1.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#    ---------------------------------------- 97.9/97.9 kB 5.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/227.3 kB ? eta -:--:--
#    --------------------------------- ----- 194.6/227.3 kB 11.5 MB/s eta 0:00:01
#    --------------------------------- ----- 194.6/227.3 kB 11.5 MB/s eta 0:00:01
#    --------------------------------- ----- 194.6/227.3 kB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 227.3/227.3 kB 1.3 MB/s eta 0:00:00
# ...

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import logging

# %%
flipcart_url = "https://www.flipkart.com/search?q=" + "iphone14pro"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone14pro'

# %%
urlclent = uReq(flipcart_url)

# %%
urlclent

# %%
flipcart_page = urlclent.read()

# %%
flipcart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.47c551.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
flipcart_html = bs(flipcart_page, 'html.parser')

# %%
"https://www.flipkart.com/"+"apple-iphone-14-pro-space-black-256-gb/p/itmbf9b9d0d108a7?pid=MOBGHWFHMSKYWVTR&lid=LSTMOBGHWFHMSKYWVTRKZV7U3&marketplace=FLIPKART&q=iphone14pro&store=tyy%2F4io&srno=s_1_3&otracker=search&iid=6259b808-4cb8-4155-8cee-f7af8c483b26.MOBGHWFHMSKYWVTR.SEARCH&ssid=mmplk6k7uo0000001716449828725&qH=1b57eea67220f216"
# Out:
# 'https://www.flipkart.com/apple-iphone-14-pro-space-black-256-gb/p/itmbf9b9d0d108a7?pid=MOBGHWFHMSKYWVTR&lid=LSTMOBGHWFHMSKYWVTRKZV7U3&marketplace=FLIPKART&q=iphone14pro&store=tyy%2F4io&srno=s_1_3&otracker=search&iid=6259b808-4cb8-4155-8cee-f7af8c483b26.MOBGHWFHMSKYWVTR.SEARCH&ssid=mmplk6k7uo0000001716449828725&qH=1b57eea67220f216'

# %%
bigbox = flipcart_html.findAll("div",{"class": "cPHDOP col-12-12"})

# %%
len(bigbox)
# Out:
# 29

# %%
del bigbox[0:3]

# %%
productlink = "https://www.flipkart.com" + bigbox[3].div.div.div.a['href']

# %%
product_request = requests.get(productlink)

# %%
productlink
# Out:
# 'https://www.flipkart.com/apple-iphone-14-pro-silver-256-gb/p/itm769b7792c9a08?pid=MOBGHWFHW5BBUGP9&lid=LSTMOBGHWFHW5BBUGP9RWUBV3&marketplace=FLIPKART&q=iphone14pro&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=b144a496-593f-4983-9e52-dd262e533066.MOBGHWFHW5BBUGP9.SEARCH&ppt=None&ppn=None&ssid=xvwga17omo0000001716450254289&qH=1b57eea67220f216'

# %%
product_html = bs(product_request.text, 'html.parser')

# %%
commentbox = product_html.findAll("div",{"class" : "RcXBOT d7A196"})

# %%
len(commentbox)
# Out:
# 7

# %%
commentbox[0].div.div.find_all('p',{"class":"_2NsDsF AwS1CA"})[0].text
# Out:
# 'Dr Ch Ravi Shanker '

# %%
for i in commentbox:
    print(i.div.div.find_all('p',{"class":"_2NsDsF AwS1CA"})[0].text)
# Out:
# Dr Ch Ravi Shanker
# Flipkart Customer
# Ashutosh Gupta
# Rishabh Srivastava
# Subham Roy
# Flipkart Customer
# Flipkart Customer

# %%
commentbox[0].div.div.div.div.text
# Out:
# '5'

# %%
for i in commentbox:
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 5
# 5
# 5
# 5

# %%
commentbox[0].div.div.div.p.text
# Out:
# 'Brilliant'

# %%
for i in commentbox:
    print(i.div.div.div.p.text)
# Out:
# Brilliant
# Worth every penny
# Great product
# Highly recommended
# Must buy!
# Highly recommended
# Brilliant

# %%
commentbox[0].div.div.find_all('div',{"class":''})[0].div.text
# Out:
# 'Awesome iPhone with best camera quality 48 megapixel is 👌'

# %%
for i in commentbox:
    print(i.div.div.find_all('div',{"class":''})[0].div.text)
# Out:
# Awesome iPhone with best camera quality 48 megapixel is 👌
# CAMERA IS SUPERB
# Camera Awesome and overall mobile look is Cool
# Just Awesome Best phone forever and Good Gaming Experience and Battery life .Specially Camera superb ❤️❤️❤️
# Awesome 😎🍫🥰
# Excellent product awesome camera super fast
# My first iPhone.. And full satisfied..

# %%
for i in bigbox:
    print("https://www.flipkart.com"+i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/apple-iphone-14-pro-silver-1-tb/p/itm87b6f4daf8cd0?pid=MOBGHWFHSY5K7VGA&lid=LSTMOBGHWFHSY5K7VGAYAMQ7W&marketplace=FLIPKART&q=iphone14pro&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=b144a496-593f-4983-9e52-dd262e533066.MOBGHWFHSY5K7VGA.SEARCH&ppt=None&ppn=None&ssid=xvwga17omo0000001716450254289&qH=1b57eea67220f216
# https://www.flipkart.com/apple-iphone-14-pro-silver-512-gb/p/itm7e2568f4b25ad?pid=MOBGHWFHYTAUDTNG&lid=LSTMOBGHWFHYTAUDTNGS2ZXK3&marketplace=FLIPKART&q=iphone14pro&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=b144a496-593f-4983-9e52-dd262e533066.MOBGHWFHYTAUDTNG.SEARCH&ppt=None&ppn=None&ssid=xvwga17omo0000001716450254289&qH=1b57eea67220f216
# ...
